# %%
import matplotlib.pyplot as plt
import scipy
import numpy as np
import time

# %% [markdown]
# # Experiment 1

# %%
groups = {"SVC": 0, "Trees": 1, "NB": 2, "Neighbors":3, "Linear":4, "DA":5, "nn":6, "Dummy":7}
labels = ["SVC", "Trees", "NB", "Neighbors", "Linear", "DA", "Network", "Dummy"]
dir = "experiment1/finalgraphs"

def create_MAE_hist(mean_absolute_errors):
    log_data = np.log10(mean_absolute_errors)
    n_bins = 40
    log_bins = np.linspace(min(log_data), max(log_data), n_bins + 1)
    bins = 10**log_bins
    plt.hist(mean_absolute_errors, bins=bins, density=True)
    plt.title(f"Distribution of the Mean absolute error. Train:{trained_on}, Eval:{eval_on}")
    
    kde = scipy.stats.gaussian_kde(mean_absolute_errors)
    x_vals = np.linspace(min(mean_absolute_errors), max(mean_absolute_errors), 500)
    plt.xscale("log")
    plt.plot(x_vals, kde(x_vals), 'r-', linewidth=2, label='KDE')

for trained_on in groups.keys():
    # baseline_dir = f"experiment1/trained{trained_on}/eval{trained_on}/aggregate/data_summary_trained{trained_on}_eval{trained_on}.txt"
    # with open(baseline_dir, 'r') as baseline_file:
    #         lines_baseline = baseline_file.readlines()
    # baseline_population = eval(lines_baseline[0])
    
    for eval_on in groups.keys(): 
        for i in [1,8,42]:
            # f"experiment1/trained{trained_on}/eval{eval_on}/aggregate/data_summary_trained{trained_on}_eval{eval_on}.txt"
            file_dir = f"experiment1/trained{trained_on}/eval{eval_on}/state{i}/data_summary.txt"
            with open(file_dir, 'r') as file:
                lines = file.readlines()
                
            # print(trained_on + eval_on + lines[1])
            population_2 = scipy.stats.zscore(eval(lines[0]))
            print(f"{np.average(population_2)} {np.std(population_2)}")
            
            ks_test = scipy.stats.kstest(population_2, 'norm')
            if ks_test.pvalue > 0.05:
                create_MAE_hist(population_2)
                plt.show()
            else:
                print(f"{trained_on}, {eval_on} state{i} is not normally distributed. pvalue:{ks_test.pvalue}")
# Out:
# -1.5983287086790765e-16 1.0
# SVC, SVC state1 is not normally distributed. pvalue:1.5902372990363732e-90
# 1.1844622228999586e-16 1.0
# SVC, SVC state8 is not normally distributed. pvalue:1.1259573928139247e-56
# 8.200146979343338e-17 1.0
# SVC, SVC state42 is not normally distributed. pvalue:1.4141489301094115e-98
# 1.63866358022829e-16 1.0
# SVC, Trees state1 is not normally distributed. pvalue:7.695598606274047e-83
# -1.8207373113647665e-17 1.0
# SVC, Trees state8 is not normally distributed. pvalue:5.657347216360432e-153
# -2.73110596704715e-17 1.0
# SVC, Trees state42 is not normally distributed. pvalue:1.550111199687418e-163
# 8.094585734336981e-17 1.0
# SVC, NB state1 is not normally distributed. pvalue:2.222792182520586e-99
# 3.5616177231082714e-17 1.0
# SVC, NB state8 is not normally distributed. pvalue:2.259278319320787e-121
# -2.5902674349878338e-17 1.0
# SVC, NB state42 is not normally distributed. pvalue:2.1083227661845513e-136
# 1.1396034254372096e-16 1.0
# SVC, Neighbors state1 is not normally distributed. pvalue:2.1490248025374055e-37
# 1.19658359670907e-16 0.9999999999999998
# SVC, Neighbors state8 is not normally distributed. pvalue:1.2416366447877235e-48
# 1.7094051381558144e-17 0.9999999999999999
# SVC, Neighbors state42 is not normally distributed. pvalue:8.479236126407655e-73
# 7.300487251347955e-17 0.9999999999999999
# SVC, Linear state1 is not normally distributed. pvalue:1.2641552457563304e-73
# -6.38792634492946e-17 0.9999999999999999
# SVC, Linear state8 is not normally distributed. pvalue:9.699771173114785e-127
# -5.70350566511559e-17 0.9999999999999999
# SVC, Linear state42 is not normally distributed. pvalue:2.3811433501624604e-160
# 4.6139138685720794e-17 1.0
# SVC, DA state1 is not normally distributed. pvalue:3.982393885483217e-73
# 1.2688263138573217e-16 1.0
# SVC, DA state8 is not normally distributed. pvalue:2.7487750560971554e-82
# -1.1534784671430199e-17 1.0
# SVC, DA state42 is not normally distributed. pvalue:6.905415137380399e-84
# -1.0240007400866136e-16 1.0
# SVC, nn state1 is not normally distributed. pvalue:9.850110851904282e-18
# -6.826671600577423e-17 0.9999999999999999
# SVC, nn state8 is not normally distributed. pvalue:6.858906673488333e-40
# -2.844446500240593e-17 1.0
# SVC, nn state42 is not normally distributed. pvalue:8.762383592387126e-47
# 1.9342236201636034e-16 1.0
# SVC, Dummy state1 is not normally distributed. pvalue:1.2653865653696367e-36
# -9.102228800769898e-17 1.0
# SVC, Dummy state8 is not normally distributed. pvalue:4.900179826594272e-30
# -1.0240007400866136e-16 1.0
# SVC, Dummy state42 is not normally distributed. pvalue:2.0821266795842007e-17
# -1.0274970270079777e-16 1.0
# Trees, SVC state1 is not normally distributed. pvalue:4.031410572820138e-176
# -1.0274970270079777e-16 1.0
# Trees, SVC state8 is not normally distributed. pvalue:3.1257757843499594e-215
# -6.279148498382087e-17 1.0
# Trees, SVC state42 is not normally distributed. pvalue:1.367304893756191e-155
# -9.103686556823833e-18 1.0
# Trees, Trees state1 is not normally distributed. pvalue:3.1556557994096733e-107
# 7.729124788446474e-17 0.9999999999999999
# Trees, Trees state8 is not normally distributed. pvalue:0.0
# 6.997189581265796e-17 1.0
# Trees, Trees state42 is not normally distributed. pvalue:0.0
# -2.5902674349878338e-17 0.9999999999999998
# Trees, NB state1 is not normally distributed. pvalue:1.9910394567352637e-161
# -1.327512060431265e-16 1.0
# Trees, NB state8 is not normally distributed. pvalue:9.615643045865287e-225
# 4.20918458185523e-17 1.0
# Trees, NB state42 is not normally distributed. pvalue:6.1509886850326576e-170
# -2.2792068508744192e-17 1.0
# Trees, Neighbors state1 is not normally distributed. pvalue:5.440206427585705e-40
# 1.0256430828934886e-16 1.0
# Trees, Neighbors state8 is not normally distributed. pvalue:4.299281064639982e-107
# -1.538464624340233e-16 1.0
# Trees, Neighbors state42 is not normally distributed. pvalue:4.282745967565594e-66
# -2.281402266046236e-18 0.9999999999999999
# Trees, Linear state1 is not normally distributed. pvalue:1.5720616926672786e-126
# 1.2319572236649675e-16 0.9999999999999999
# Trees, Linear state8 is not normally distributed. pvalue:1.3866335879023474e-193
# -1.916377903478838e-16 1.0
# Trees, Linear state42 is not normally distributed. pvalue:2.12668737125081e-171
# -4.6139138685720794e-17 1.0
# Trees, DA state1 is not normally distributed. pvalue:2.510072440910965e-60
# 1.0958045437858688e-16 1.0
# Trees, DA state8 is not normally distributed. pvalue:3.145044443858724e-93
# 7.497610036429629e-17 1.0
# Trees, DA state42 is not normally distributed. pvalue:1.8092945381287374e-78
# 3.98222510033683e-17 1.0
# Trees, nn state1 is not normally distributed. pvalue:3.9749444620026765e-49
# 1.1377786000962372e-17 1.0
# Trees, nn state8 is not normally distributed. pvalue:7.967602839035354e-72
# -1.0808896700914254e-16 1.0
# Trees, nn state42 is not normally distributed. pvalue:4.962596919064535e-55
# -3.4133358002887116e-17 1.0
# Trees, Dummy state1 is not normally distributed. pvalue:1.7948018848196434e-73
# -7.395560900625542e-17 1.0
# Trees, Dummy state8 is not normally distributed. pvalue:1.3337123879974304e-112
# 1.0240007400866136e-16 1.0
# Trees, Dummy state42 is not normally distributed. pvalue:2.0259017155751194e-74
# 3.4249900900265927e-17 1.0
# NB, SVC state1 is not normally distributed. pvalue:5.435811010221157e-41
# -2.1120772221830655e-16 1.0
# NB, SVC state8 is not normally distributed. pvalue:1.2371000370585193e-103
# 5.422900975875438e-17 1.0
# NB, SVC state42 is not normally distributed. pvalue:2.265819107624618e-118
# 2.0028110425012433e-16 1.0
# NB, Trees state1 is not normally distributed. pvalue:5.99681403674363e-32
# -1.8207373113647665e-17 1.0
# NB, Trees state8 is not normally distributed. pvalue:6.278996238786864e-212
# 2.0028110425012433e-16 1.0
# NB, Trees state42 is not normally distributed. pvalue:8.396259992394656e-105
# 4.5329680112287093e-17 1.0
# NB, NB state1 is not normally distributed. pvalue:3.854879310098415e-89
# 2.2664840056143547e-17 1.0000000000000002
# NB, NB state8 is not normally distributed. pvalue:2.056714280625766e-148
# -7.272361101057085e-17 1.0
# NB, NB state42 is not normally distributed. pvalue:1.576112907611223e-169
# -9.116827403497677e-17 0.9999999999999998
# NB, Neighbors state1 is not normally distributed. pvalue:7.103001597063713e-43
# -6.552719696263955e-17 1.0
# NB, Neighbors state8 is not normally distributed. pvalue:1.437861048437051e-63
# -7.12252140898256e-17 1.0
# NB, Neighbors state42 is not normally distributed. pvalue:1.7002510272204707e-72
# 2.555170537971784e-16 1.0
# NB, Linear state1 is not normally distributed. pvalue:8.980236003793318e-81
# -1.8251218128369888e-17 1.0
# NB, Linear state8 is not normally distributed. pvalue:5.5782393288981055e-183
# 8.21304815776645e-17 0.9999999999999999
# NB, Linear state42 is not normally distributed. pvalue:1.0984803964702567e-157
# 9.227827737144159e-17 1.0
# NB, DA state1 is not normally distributed. pvalue:6.958344961081549e-34
# -1.0381306204287178e-16 1.0
# NB, DA state8 is not normally distributed. pvalue:1.881967682393357e-86
# 8.074349270001139e-17 1.0000000000000002
# NB, DA state42 is not normally distributed. pvalue:7.170341151454154e-119
# 9.102228800769898e-17 1.0
# NB, nn state1 is not normally distributed. pvalue:5.183154070203226e-12
# 1.592890040134732e-16 1.0
# NB, nn state8 is not normally distributed. pvalue:8.816252978846832e-49
# 0.0 1.0
# NB, nn state42 is not normally distributed. pvalue:1.2524688273116904e-50
# 1.251556460105861e-16 1.0
# NB, Dummy state1 is not normally distributed. pvalue:2.4572152515284417e-57
# -3.98222510033683e-17 1.0
# NB, Dummy state8 is not normally distributed. pvalue:3.51564797537582e-63
# -4.551114400384949e-17 1.0
# NB, Dummy state42 is not normally distributed. pvalue:2.927500592519476e-142
# -5.708316816710988e-17 1.0
# Neighbors, SVC state1 is not normally distributed. pvalue:1.732995374009502e-60
# 1.1416633633421975e-17 1.0
# Neighbors, SVC state8 is not normally distributed. pvalue:6.44022714389372e-172
# 1.7124950450132963e-17 1.0
# Neighbors, SVC state42 is not normally distributed. pvalue:1.7561075858391135e-207
# 1.5476267146600516e-16 1.0
# Neighbors, Trees state1 is not normally distributed. pvalue:5.253540467301257e-43
# 4.096658950570725e-17 0.9999999999999998
# Neighbors, Trees state8 is not normally distributed. pvalue:5.900399680309299e-181
# 1.365552983523575e-17 0.9999999999999999
# Neighbors, Trees state42 is not normally distributed. pvalue:1.7269114304140213e-172
# 1.1656203457445253e-16 0.9999999999999998
# Neighbors, NB state1 is not normally distributed. pvalue:1.5896884506299425e-84
# -9.713502881204378e-18 1.0
# Neighbors, NB state8 is not normally distributed. pvalue:1.3229336003723765e-183
# -1.2951337174939169e-17 1.0
# Neighbors, NB state42 is not normally distributed. pvalue:5.498636722932004e-223
# 1.7663853094276749e-16 0.9999999999999999
# Neighbors, Neighbors state1 is not normally distributed. pvalue:3.856562272261728e-48
# 8.599609509955827e-17 1.0
# Neighbors, Neighbors state8 is not normally distributed. pvalue:9.074992055996465e-172
# -4.3742530866339376e-17 0.9999999999999999
# Neighbors, Neighbors state42 is not normally distributed. pvalue:7.430740002058428e-154
# 1.277585268985892e-16 1.0
# Neighbors, Linear state1 is not normally distributed. pvalue:5.39163305304139e-62
# 5.019084985301719e-17 1.0
# Neighbors, Linear state8 is not normally distributed. pvalue:1.3689535290675745e-196
# -1.0950730877021933e-16 1.0
# Neighbors, Linear state42 is not normally distributed. pvalue:1.4894453978368455e-166
# 1.1534784671430197e-16 1.0
# Neighbors, DA state1 is not normally distributed. pvalue:1.7344348976244804e-40
# -2.883696167857549e-17 1.0
# Neighbors, DA state8 is not normally distributed. pvalue:7.662430579124389e-78
# -1.0958045437858688e-16 1.0
# Neighbors, DA state42 is not normally distributed. pvalue:4.9142308991880165e-81
# -2.2755572001924744e-17 1.0
# Neighbors, nn state1 is not normally distributed. pvalue:4.79480450579283e-07
# 8.53333950072178e-17 1.0
# Neighbors, nn state8 is not normally distributed. pvalue:2.0567634092947642e-36
# 3.4133358002887116e-17 1.0
# Neighbors, nn state42 is not normally distributed. pvalue:1.771982347591853e-30
# 1.0240007400866136e-16 1.0
# Neighbors, Dummy state1 is not normally distributed. pvalue:2.1973505840400645e-46
# -5.688893000481186e-18 1.0
# Neighbors, Dummy state8 is not normally distributed. pvalue:1.0928690682870911e-113
# 1.0808896700914254e-16 1.0
# Neighbors, Dummy state42 is not normally distributed. pvalue:1.248785367702714e-122
# -1.0274970270079777e-16 1.0
# Linear, SVC state1 is not normally distributed. pvalue:7.036601410690726e-25
# 9.704138588408679e-17 1.0
# Linear, SVC state8 is not normally distributed. pvalue:1.618915151281998e-82
# 2.283326726684395e-17 1.0
# Linear, SVC state42 is not normally distributed. pvalue:1.0207387155081349e-84
# 7.738133573300258e-17 1.0
# Linear, Trees state1 is not normally distributed. pvalue:1.1313761689165369e-21
# 1.911774176933005e-16 1.0
# Linear, Trees state8 is not normally distributed. pvalue:1.4320173653703179e-78
# -2.503513803126554e-17 1.0
# Linear, Trees state42 is not normally distributed. pvalue:1.3362189568287678e-76
# -8.25647744902372e-17 1.0
# Linear, NB state1 is not normally distributed. pvalue:5.54169175015798e-73
# -4.5329680112287093e-17 1.0
# Linear, NB state8 is not normally distributed. pvalue:2.0688454725340755e-123
# 4.856751440602189e-18 1.0
# Linear, NB state42 is not normally distributed. pvalue:7.866451155680528e-95
# 2.279206850874419e-16 0.9999999999999999
# Linear, Neighbors state1 is not normally distributed. pvalue:5.278306753426383e-20
# 1.3675241105246515e-16 1.0
# Linear, Neighbors state8 is not normally distributed. pvalue:8.059328205425256e-36
# 4.5584137017488383e-17 1.0
# Linear, Neighbors state42 is not normally distributed. pvalue:1.698432534961506e-33
# -9.125609064184943e-17 0.9999999999999999
# Linear, Linear state1 is not normally distributed. pvalue:2.0349107465096265e-27
# 2.539189667464925e-16 1.0
# Linear, Linear state8 is not normally distributed. pvalue:9.018118397973092e-78
# -3.498594790632898e-17 0.9999999999999998
# Linear, Linear state42 is not normally distributed. pvalue:1.0826807257383553e-118
# 1.9609133941431335e-16 1.0
# Linear, DA state1 is not normally distributed. pvalue:2.1042843249636193e-23
# 1.0381306204287178e-16 1.0
# Linear, DA state8 is not normally distributed. pvalue:1.923715045630569e-50
# 3.460435401429059e-17 1.0
# Linear, DA state42 is not normally distributed. pvalue:1.5435525198193432e-47
# -5.688893000481186e-18 1.0
# Linear, nn state1 is not normally distributed. pvalue:1.4656750346649846e-09
# -9.671118100818017e-17 1.0
# Linear, nn state8 is not normally distributed. pvalue:2.0094496586026134e-28
# -8.53333950072178e-17 1.0
# Linear, nn state42 is not normally distributed. pvalue:8.180455240579311e-35
# 7.96445020067366e-17 1.0
# Linear, Dummy state1 is not normally distributed. pvalue:9.842070393605928e-26
# -6.826671600577423e-17 1.0
# Linear, Dummy state8 is not normally distributed. pvalue:1.1074498138203077e-50
# 1.0240007400866136e-16 1.0
# Linear, Dummy state42 is not normally distributed. pvalue:4.4191018208017334e-54
# -2.8541584083554938e-18 1.0
# DA, SVC state1 is not normally distributed. pvalue:3.0083792491494316e-82
# 2.283326726684395e-17 0.9999999999999998
# DA, SVC state8 is not normally distributed. pvalue:3.277886949592079e-160
# 7.991643543395383e-17 1.0
# DA, SVC state42 is not normally distributed. pvalue:1.2844744168149577e-110
# 1.4565898490918132e-16 1.0
# DA, Trees state1 is not normally distributed. pvalue:2.349944540448616e-185
# 5.4622119340943e-17 1.0
# DA, Trees state8 is not normally distributed. pvalue:1.7642266596584634e-190
# 5.234619770173704e-17 1.0
# DA, Trees state42 is not normally distributed. pvalue:9.295179840207458e-120
# 7.770802304963502e-17 1.0
# DA, NB state1 is not normally distributed. pvalue:6.946658216490393e-106
# -3.5616177231082714e-17 0.9999999999999999
# DA, NB state8 is not normally distributed. pvalue:3.0017648962582e-139
# 1.9427005762408756e-17 1.0
# DA, NB state42 is not normally distributed. pvalue:6.250574557705722e-137
# 4.273512845389536e-17 1.0
# DA, Neighbors state1 is not normally distributed. pvalue:4.409383649621875e-48
# -1.5954447956120934e-16 1.0
# DA, Neighbors state8 is not normally distributed. pvalue:3.398378054534494e-82
# -2.5641077072337216e-17 1.0
# DA, Neighbors state42 is not normally distributed. pvalue:1.8363466610465784e-61
# -9.125609064184944e-18 1.0
# DA, Linear state1 is not normally distributed. pvalue:3.5667692108416735e-156
# 9.125609064184943e-17 1.0
# DA, Linear state8 is not normally distributed. pvalue:5.92919804814088e-176
# 1.277585268985892e-16 1.0
# DA, Linear state42 is not normally distributed. pvalue:1.6504664031740811e-158
# -1.7302177007145296e-17 1.0
# DA, DA state1 is not normally distributed. pvalue:8.372391333967263e-60
# -7.729291608889979e-17 1.0
# DA, DA state8 is not normally distributed. pvalue:3.754622897586578e-62
# -9.008465746562285e-17 1.0
# DA, DA state42 is not normally distributed. pvalue:7.792199644614879e-66
# 4.8355590504090085e-17 1.0
# DA, nn state1 is not normally distributed. pvalue:2.75954215634638e-26
# -6.542226950553365e-17 0.9999999999999999
# DA, nn state8 is not normally distributed. pvalue:7.552795506025391e-38
# -7.680005550649602e-17 1.0
# DA, nn state42 is not normally distributed. pvalue:6.646944522746123e-32
# 3.98222510033683e-17 1.0
# DA, Dummy state1 is not normally distributed. pvalue:3.4619145111580284e-83
# -1.9342236201636034e-16 1.0
# DA, Dummy state8 is not normally distributed. pvalue:4.0275243395266224e-97
# -1.8204457601539795e-16 1.0
# DA, Dummy state42 is not normally distributed. pvalue:1.9900904259722724e-54
# -1.9408277176817357e-16 0.9999999999999998
# nn, SVC state1 is not normally distributed. pvalue:4.9084930577257236e-170
# 1.312912867843527e-16 1.0
# nn, SVC state8 is not normally distributed. pvalue:1.680129768844705e-173
# 6.849980180053185e-17 1.0
# nn, SVC state42 is not normally distributed. pvalue:6.326347590281005e-150
# -2.73110596704715e-17 0.9999999999999999
# nn, Trees state1 is not normally distributed. pvalue:1.5150258641104898e-219
# -9.558870884665025e-17 1.0
# nn, Trees state8 is not normally distributed. pvalue:7.64481017103172e-173
# 1.6841820130124092e-16 1.0
# nn, Trees state42 is not normally distributed. pvalue:2.0788588116297513e-159
# -3.885401152481751e-17 0.9999999999999999
# nn, NB state1 is not normally distributed. pvalue:2.1088298259899863e-108
# -3.5616177231082714e-17 1.0
# nn, NB state8 is not normally distributed. pvalue:3.727468534101881e-130
# 8.09458573433698e-18 1.0
# nn, NB state42 is not normally distributed. pvalue:5.950212245040393e-130
# 1.1396034254372096e-17 0.9999999999999999
# nn, Neighbors state1 is not normally distributed. pvalue:3.4652295500296395e-48
# -1.2535637679809305e-16 1.0000000000000002
# nn, Neighbors state8 is not normally distributed. pvalue:7.519983269450394e-53
# -4.5584137017488383e-17 0.9999999999999999
# nn, Neighbors state42 is not normally distributed. pvalue:9.331589723963166e-48
# -9.125609064184943e-17 1.0
# nn, Linear state1 is not normally distributed. pvalue:1.0784331225789639e-110
# 7.756767704557202e-17 1.0
# nn, Linear state8 is not normally distributed. pvalue:4.604914347293641e-132
# 9.58188951739419e-17 1.0
# nn, Linear state42 is not normally distributed. pvalue:1.809740367855701e-107
# -4.6139138685720794e-17 0.9999999999999999
# nn, DA state1 is not normally distributed. pvalue:1.9044026652480212e-84
# -2.0762612408574356e-16 1.0
# nn, DA state8 is not normally distributed. pvalue:8.248835082867178e-94
# -8.074349270001139e-17 1.0
# nn, DA state42 is not normally distributed. pvalue:2.4672111405052495e-88
# 1.1377786000962372e-16 0.9999999999999998
# nn, nn state1 is not normally distributed. pvalue:6.0439816783149095e-34
# 0.0 0.9999999999999999
# nn, nn state8 is not normally distributed. pvalue:1.2819917318994506e-41
# -4.375936786821248e-17 1.0
# nn, nn state42 is not normally distributed. pvalue:1.215072208953007e-49
# 7.96445020067366e-17 1.0
# nn, Dummy state1 is not normally distributed. pvalue:7.543683515778378e-108
# 9.102228800769898e-17 1.0
# nn, Dummy state8 is not normally distributed. pvalue:8.954564752728314e-114
# 1.4791121801251085e-16 0.9999999999999998
# nn, Dummy state42 is not normally distributed. pvalue:1.1763069396331923e-113
# 4.56665345336879e-17 1.0
# Dummy, SVC state1 is not normally distributed. pvalue:2.706489394357104e-51
# 1.1416633633421975e-17 1.0
# Dummy, SVC state8 is not normally distributed. pvalue:3.438394598236509e-147
# 2.854158408355494e-17 1.0
# Dummy, SVC state42 is not normally distributed. pvalue:4.803356648781519e-162
# -2.18488477363772e-16 1.0
# Dummy, Trees state1 is not normally distributed. pvalue:5.737226320242372e-66
# -1.1379608196029791e-16 0.9999999999999998
# Dummy, Trees state8 is not normally distributed. pvalue:4.816828540527573e-128
# -7.282949245459066e-17 1.0
# Dummy, Trees state42 is not normally distributed. pvalue:3.696359297473308e-177
# 1.618917146867396e-17 1.0
# Dummy, NB state1 is not normally distributed. pvalue:6.793098816140054e-91
# 2.7521591496745736e-17 0.9999999999999998
# Dummy, NB state8 is not normally distributed. pvalue:6.121258376274555e-147
# -1.2951337174939169e-17 0.9999999999999998
# Dummy, NB state42 is not normally distributed. pvalue:1.9153923911650157e-164
# -1.5954447956120934e-16 1.0
# Dummy, Neighbors state1 is not normally distributed. pvalue:9.978288348310124e-53
# 1.424504281796512e-16 1.0
# Dummy, Neighbors state8 is not normally distributed. pvalue:1.9527069242829756e-82
# 1.8233654806995353e-16 1.0
# Dummy, Neighbors state42 is not normally distributed. pvalue:4.298405303931125e-97
# -9.125609064184943e-17 1.0
# Dummy, Linear state1 is not normally distributed. pvalue:6.115430994851128e-56
# -1.5513535409114405e-16 1.0
# Dummy, Linear state8 is not normally distributed. pvalue:2.861244116219629e-174
# -4.5628045320924716e-17 0.9999999999999998
# Dummy, Linear state42 is not normally distributed. pvalue:1.6689178469483841e-178
# -6.344131569286608e-17 0.9999999999999999
# Dummy, DA state1 is not normally distributed. pvalue:6.13366235555583e-27
# 1.874402509107407e-16 1.0
# Dummy, DA state8 is not normally distributed. pvalue:1.7915628429121302e-62
# -7.497610036429629e-17 1.0
# Dummy, DA state42 is not normally distributed. pvalue:8.32023591142522e-44
# 3.98222510033683e-17 1.0
# Dummy, nn state1 is not normally distributed. pvalue:1.4712911767218417e-10
# 2.076445945175633e-16 1.0
# Dummy, nn state8 is not normally distributed. pvalue:1.2205574212976134e-26
# -1.7066679001443558e-17 0.9999999999999999
# Dummy, nn state42 is not normally distributed. pvalue:5.1644275245513923e-26
# 1.4791121801251085e-16 1.0
# Dummy, Dummy state1 is not normally distributed. pvalue:6.67327210031838e-34
# 1.0733273954080063e-17 1.0000000000000002
# Dummy, Dummy state8 is not normally distributed. pvalue:5.892545770544045e-43
# -1.7503747147284992e-16 1.0
# Dummy, Dummy state42 is not normally distributed. pvalue:1.3458207718115496e-79

# %% [markdown]
# # Experiment 2

# %%
groups = {"LDA": 0, "QDA": 1, "Trees": 2}
labels = ["LDA", "QDA", "Trees"]
dir = "experiment2/finalgraphs"

def create_MAE_hist(mean_absolute_errors):
    log_data = np.log10(mean_absolute_errors)
    n_bins = 40
    log_bins = np.linspace(min(log_data), max(log_data), n_bins + 1)
    bins = 10**log_bins
    plt.hist(mean_absolute_errors, bins=bins, density=True)
    plt.title(f"Distribution of the Mean absolute error. Train:{trained_on}, Eval:{eval_on}")
    
    kde = scipy.stats.gaussian_kde(mean_absolute_errors)
    x_vals = np.linspace(min(mean_absolute_errors), max(mean_absolute_errors), 500)
    plt.xscale("log")
    plt.plot(x_vals, kde(x_vals), 'r-', linewidth=2, label='KDE')

for trained_on in groups.keys():
    # baseline_dir = f"experiment1/trained{trained_on}/eval{trained_on}/aggregate/data_summary_trained{trained_on}_eval{trained_on}.txt"
    # with open(baseline_dir, 'r') as baseline_file:
    #         lines_baseline = baseline_file.readlines()
    # baseline_population = eval(lines_baseline[0])
    
    for eval_on in groups.keys(): 
        for i in [1,8,42]:
            # f"experiment1/trained{trained_on}/eval{eval_on}/aggregate/data_summary_trained{trained_on}_eval{eval_on}.txt"
            file_dir = f"experiment2/trained{trained_on}/eval{eval_on}/state{i}augment/data_summary.txt"
            with open(file_dir, 'r') as file:
                lines = file.readlines()
                
            # print(trained_on + eval_on + lines[1])
            population_2 = scipy.stats.zscore(eval(lines[0]))
            print(f"transformed distribution stats: avg:{np.average(population_2)} std:{np.std(population_2)}")
            
            ks_test = scipy.stats.kstest(population_2, 'norm')
            if ks_test.pvalue > 0.05:
                create_MAE_hist(population_2)
                plt.show()
            else:
                print(f"{trained_on}, {eval_on} state{i} is not normally distributed. pvalue:{ks_test.pvalue}")
# Out:
# transformed distribution stats: avg:-5.973337650505246e-17 std:1.0
# LDA, LDA state1 is not normally distributed. pvalue:2.3403341704536187e-69
# transformed distribution stats: avg:5.366636977040032e-17 std:1.0
# LDA, LDA state8 is not normally distributed. pvalue:9.836493699744073e-66
# transformed distribution stats: avg:1.093984196705312e-17 std:1.0
# LDA, LDA state42 is not normally distributed. pvalue:2.3612219785627784e-69
# transformed distribution stats: avg:1.1705811132785835e-17 std:1.0
# LDA, QDA state1 is not normally distributed. pvalue:8.277486654739258e-55
# transformed distribution stats: avg:2.341162226557167e-17 std:1.0
# LDA, QDA state8 is not normally distributed. pvalue:1.2193134821386554e-51
# transformed distribution stats: avg:-5.852905566392917e-17 std:1.0
# LDA, QDA state42 is not normally distributed. pvalue:2.7889132390329203e-46
# transformed distribution stats: avg:2.0483294752853626e-16 std:1.0
# LDA, Trees state1 is not normally distributed. pvalue:0.0
# transformed distribution stats: avg:-1.8207373113647665e-17 std:1.0
# LDA, Trees state8 is not normally distributed. pvalue:0.0
# transformed distribution stats: avg:2.2759216392059583e-17 std:1.0
# LDA, Trees state42 is not normally distributed. pvalue:0.0
# transformed distribution stats: avg:8.53333950072178e-17 std:1.0
# QDA, LDA state1 is not normally distributed. pvalue:2.2286218760711624e-49
# transformed distribution stats: avg:7.96445020067366e-17 std:1.0
# QDA, LDA state8 is not normally distributed. pvalue:5.01686481148167e-49
# transformed distribution stats: avg:-8.533339500721779e-18 std:1.0
# QDA, LDA state42 is not normally distributed. pvalue:8.067357594598307e-39
# transformed distribution stats: avg:-3.51174333983575e-17 std:1.0
# QDA, QDA state1 is not normally distributed. pvalue:3.22724669741305e-40
# transformed distribution stats: avg:-1.4791121801251085e-16 std:0.9999999999999998
# QDA, QDA state8 is not normally distributed. pvalue:2.2191810065711156e-36
# transformed distribution stats: avg:2.554238592601667e-16 std:1.0
# QDA, QDA state42 is not normally distributed. pvalue:2.3694434976642986e-13
# transformed distribution stats: avg:9.103686556823833e-18 std:1.0
# QDA, Trees state1 is not normally distributed. pvalue:9.811239903421217e-180
# transformed distribution stats: avg:4.551843278411916e-18 std:0.9999999999999999
# QDA, Trees state8 is not normally distributed. pvalue:0.0
# transformed distribution stats: avg:1.2745161179553366e-16 std:1.0
# QDA, Trees state42 is not normally distributed. pvalue:3.849481122205971e-76
# transformed distribution stats: avg:5.688893000481186e-18 std:1.0
# Trees, LDA state1 is not normally distributed. pvalue:9.418845501048598e-35
# transformed distribution stats: avg:7.395560900625542e-17 std:1.0
# Trees, LDA state8 is not normally distributed. pvalue:1.3496546061251262e-46
# transformed distribution stats: avg:2.2755572001924744e-17 std:1.0000000000000002
# Trees, LDA state42 is not normally distributed. pvalue:2.6112183856775052e-39
# transformed distribution stats: avg:-1.8144007255818045e-16 std:1.0
# Trees, QDA state1 is not normally distributed. pvalue:6.84572559029244e-33
# transformed distribution stats: avg:1.1705811132785835e-17 std:1.0
# Trees, QDA state8 is not normally distributed. pvalue:6.1616334634307765e-33
# transformed distribution stats: avg:1.6973426142539461e-16 std:1.0
# Trees, QDA state42 is not normally distributed. pvalue:1.133604141573882e-25
# transformed distribution stats: avg:2.2759216392059583e-17 std:1.0
# Trees, Trees state1 is not normally distributed. pvalue:1.145722315822157e-162
# transformed distribution stats: avg:1.374066629057151e-16 std:1.0
# Trees, Trees state8 is not normally distributed. pvalue:0.0
# transformed distribution stats: avg:8.746486976582246e-17 std:1.0
# Trees, Trees state42 is not normally distributed. pvalue:7.407118341939966e-272

# %% [markdown]
# # supplementary experiment

# %%
groups = {"LDA": 0, "QDA": 1, "Trees": 2}
labels = ["LDA", "QDA", "Trees"]
dir = "supplementary-exp/finalgraphs"

def create_MAE_hist(mean_absolute_errors):
    log_data = np.log10(mean_absolute_errors)
    n_bins = 40
    log_bins = np.linspace(min(log_data), max(log_data), n_bins + 1)
    bins = 10**log_bins
    plt.hist(mean_absolute_errors, bins=bins, density=True)
    plt.title(f"Distribution of the Mean absolute error. Train:{trained_on}, Eval:{eval_on}")
    
    kde = scipy.stats.gaussian_kde(mean_absolute_errors)
    x_vals = np.linspace(min(mean_absolute_errors), max(mean_absolute_errors), 500)
    plt.xscale("log")
    plt.plot(x_vals, kde(x_vals), 'r-', linewidth=2, label='KDE')

for trained_on in groups.keys():
    # baseline_dir = f"experiment1/trained{trained_on}/eval{trained_on}/aggregate/data_summary_trained{trained_on}_eval{trained_on}.txt"
    # with open(baseline_dir, 'r') as baseline_file:
    #         lines_baseline = baseline_file.readlines()
    # baseline_population = eval(lines_baseline[0])
    
    for eval_on in groups.keys(): 
        for i in [1,8,42]:
            for string in ["augment", "no_augment"]:
                # f"experiment1/trained{trained_on}/eval{eval_on}/aggregate/data_summary_trained{trained_on}_eval{eval_on}.txt"
                file_dir = f"supplementary-exp/trained{trained_on}/eval{eval_on}/state{i}{string}/data_summary.txt"
                with open(file_dir, 'r') as file:
                    lines = file.readlines()
                    
                # print(trained_on + eval_on + lines[1])
                population_2 = scipy.stats.zscore(eval(lines[0]))
                print(f"transformed distribution stats: avg:{np.average(population_2)} std:{np.std(population_2)}")
                
                ks_test = scipy.stats.kstest(population_2, 'norm')
                if ks_test.pvalue > 0.05:
                    create_MAE_hist(population_2)
                    plt.show()
                else:
                    print(f"{trained_on}, {eval_on} state{i} is not normally distributed. pvalue:{ks_test.pvalue}")
# Out:
# transformed distribution stats: avg:-5.973337650505246e-17 std:1.0
# LDA, LDA state1 is not normally distributed. pvalue:2.3403341704536187e-69
# transformed distribution stats: avg:6.257782300529305e-17 std:1.0
# LDA, LDA state1 is not normally distributed. pvalue:7.022760793248524e-44
# transformed distribution stats: avg:5.366636977040032e-17 std:1.0
# LDA, LDA state8 is not normally distributed. pvalue:9.836493699744073e-66
# transformed distribution stats: avg:3.219982186224019e-17 std:1.0
# LDA, LDA state8 is not normally distributed. pvalue:3.323012211304682e-34
# transformed distribution stats: avg:1.093984196705312e-17 std:1.0
# LDA, LDA state42 is not normally distributed. pvalue:2.3612219785627784e-69
# transformed distribution stats: avg:-5.4699209835265604e-17 std:0.9999999999999998
# LDA, LDA state42 is not normally distributed. pvalue:5.448706194779753e-29
# transformed distribution stats: avg:7.0234866796715e-17 std:1.0000000000000002
# LDA, QDA state1 is not normally distributed. pvalue:3.7439015834033704e-52
# transformed distribution stats: avg:2.341162226557167e-17 std:1.0
# LDA, QDA state1 is not normally distributed. pvalue:2.07117600660087e-34
# transformed distribution stats: avg:7.0234866796715e-17 std:1.0000000000000002
# LDA, QDA state8 is not normally distributed. pvalue:1.232837834385645e-52
# transformed distribution stats: avg:-1.0535230019507251e-16 std:1.0
# LDA, QDA state8 is not normally distributed. pvalue:8.122833542861501e-41
# transformed distribution stats: avg:-4.682324453114334e-17 std:1.0
# LDA, QDA state42 is not normally distributed. pvalue:2.5724473924817753e-46
# transformed distribution stats: avg:-1.5217554472621587e-16 std:1.0
# LDA, QDA state42 is not normally distributed. pvalue:1.2001609830750481e-45
# transformed distribution stats: avg:-7.282949245459066e-17 std:1.0
# LDA, Trees state1 is not normally distributed. pvalue:0.0
# transformed distribution stats: avg:-5.917396261935491e-17 std:1.0
# LDA, Trees state1 is not normally distributed. pvalue:3.483429537236386e-160
# transformed distribution stats: avg:1.3200345507394557e-16 std:1.0
# LDA, Trees state8 is not normally distributed. pvalue:0.0
# transformed distribution stats: avg:1.4565898490918132e-16 std:1.0
# LDA, Trees state8 is not normally distributed. pvalue:1.3001006827589253e-133
# transformed distribution stats: avg:-1.365552983523575e-17 std:1.0
# LDA, Trees state42 is not normally distributed. pvalue:0.0
# transformed distribution stats: avg:7.282949245459066e-17 std:1.0
# LDA, Trees state42 is not normally distributed. pvalue:2.4932753643367483e-135
# transformed distribution stats: avg:2.2755572001924744e-17 std:1.0
# QDA, LDA state1 is not normally distributed. pvalue:9.192875792734277e-52
# transformed distribution stats: avg:-1.0808896700914254e-16 std:0.9999999999999999
# QDA, LDA state1 is not normally distributed. pvalue:1.383236713649806e-51
# transformed distribution stats: avg:0.0 std:1.0
# QDA, LDA state8 is not normally distributed. pvalue:1.8485573869126145e-44
# transformed distribution stats: avg:-5.688893000481186e-17 std:0.9999999999999999
# QDA, LDA state8 is not normally distributed. pvalue:3.200291323280009e-37
# transformed distribution stats: avg:-1.1377786000962372e-17 std:1.0
# QDA, LDA state42 is not normally distributed. pvalue:1.3603696204639076e-36
# transformed distribution stats: avg:2.2755572001924744e-17 std:0.9999999999999999
# QDA, LDA state42 is not normally distributed. pvalue:1.5966435709760073e-08
# transformed distribution stats: avg:-3.51174333983575e-17 std:1.0
# QDA, QDA state1 is not normally distributed. pvalue:3.22724669741305e-40
# transformed distribution stats: avg:0.0 std:1.0
# QDA, QDA state1 is not normally distributed. pvalue:1.6284630389686996e-19
# transformed distribution stats: avg:-1.4791121801251085e-16 std:0.9999999999999998
# QDA, QDA state8 is not normally distributed. pvalue:2.2191810065711156e-36
# transformed distribution stats: avg:-1.7066679001443558e-17 std:0.9999999999999999
# QDA, QDA state8 is not normally distributed. pvalue:3.1951223276286065e-20
# transformed distribution stats: avg:2.554238592601667e-16 std:1.0
# QDA, QDA state42 is not normally distributed. pvalue:2.3694434976642986e-13
# transformed distribution stats: avg:-9.868649107779169e-17 std:1.0
# QDA, QDA state42 is not normally distributed. pvalue:3.4522654520224516e-21
# transformed distribution stats: avg:5.917396261935491e-17 std:0.9999999999999999
# QDA, Trees state1 is not normally distributed. pvalue:1.9757102600808394e-174
# transformed distribution stats: avg:-2.73110596704715e-17 std:1.0
# QDA, Trees state1 is not normally distributed. pvalue:7.087540081900026e-249
# transformed distribution stats: avg:9.103686556823833e-18 std:1.0
# QDA, Trees state8 is not normally distributed. pvalue:0.0
# transformed distribution stats: avg:5.4622119340943e-17 std:1.0
# QDA, Trees state8 is not normally distributed. pvalue:7.422377542758668e-223
# transformed distribution stats: avg:1.7297004457965282e-16 std:1.0
# QDA, Trees state42 is not normally distributed. pvalue:3.1191353559781414e-75
# transformed distribution stats: avg:2.0028110425012433e-16 std:1.0
# QDA, Trees state42 is not normally distributed. pvalue:3.828588652860863e-46
# transformed distribution stats: avg:-1.3653343201154847e-16 std:0.9999999999999999
# Trees, LDA state1 is not normally distributed. pvalue:5.323304563651864e-36
# transformed distribution stats: avg:-2.2755572001924744e-17 std:1.0
# Trees, LDA state1 is not normally distributed. pvalue:7.894979784837823e-32
# transformed distribution stats: avg:1.1377786000962372e-17 std:1.0
# Trees, LDA state8 is not normally distributed. pvalue:1.015565150846421e-46
# transformed distribution stats: avg:1.8204457601539795e-16 std:1.0
# Trees, LDA state8 is not normally distributed. pvalue:1.7279939559315252e-48
# transformed distribution stats: avg:-6.257782300529305e-17 std:0.9999999999999999
# Trees, LDA state42 is not normally distributed. pvalue:1.8493256926346883e-40
# transformed distribution stats: avg:-7.96445020067366e-17 std:1.0
# Trees, LDA state42 is not normally distributed. pvalue:1.2953289268808506e-51
# transformed distribution stats: avg:8.779358349589377e-17 std:1.0
# Trees, QDA state1 is not normally distributed. pvalue:8.620011150469554e-32
# transformed distribution stats: avg:-2.341162226557167e-17 std:1.0
# Trees, QDA state1 is not normally distributed. pvalue:6.707400760965844e-29
# transformed distribution stats: avg:-5.852905566392917e-17 std:0.9999999999999998
# Trees, QDA state8 is not normally distributed. pvalue:6.757878127512572e-32
# transformed distribution stats: avg:4.682324453114334e-17 std:1.0
# Trees, QDA state8 is not normally distributed. pvalue:1.0475348347568133e-32
# transformed distribution stats: avg:1.1705811132785835e-17 std:0.9999999999999999
# Trees, QDA state42 is not normally distributed. pvalue:3.2185360681359686e-25
# transformed distribution stats: avg:7.0234866796715e-17 std:1.0000000000000002
# Trees, QDA state42 is not normally distributed. pvalue:8.430195118945928e-39
# transformed distribution stats: avg:2.2759216392059583e-17 std:1.0
# Trees, Trees state1 is not normally distributed. pvalue:1.145722315822157e-162
# transformed distribution stats: avg:-2.18488477363772e-16 std:0.9999999999999999
# Trees, Trees state1 is not normally distributed. pvalue:5.015555838301577e-151
# transformed distribution stats: avg:1.374066629057151e-16 std:1.0
# Trees, Trees state8 is not normally distributed. pvalue:0.0
# transformed distribution stats: avg:8.158520610026834e-17 std:1.0
# Trees, Trees state8 is not normally distributed. pvalue:2.133455094354448e-93
# transformed distribution stats: avg:8.746486976582246e-17 std:1.0
# Trees, Trees state42 is not normally distributed. pvalue:7.407118341939966e-272
# transformed distribution stats: avg:1.3994379162531593e-16 std:1.0
# Trees, Trees state42 is not normally distributed. pvalue:1.0183527469293373e-267

# %% [markdown]
# # Experiment 3

# %%
groups = {"LDA": 0, "Sigmoid": 1, "Centroid": 2, "Gradient": 3, "ExtraTree":4}
labels = ["LDA", "Sigmoid", "Centroid", "Gradient", "ExtraTree"]
dir = "experiment3/finalgraphs"

def create_MAE_hist(mean_absolute_errors):
    log_data = np.log10(mean_absolute_errors)
    n_bins = 40
    log_bins = np.linspace(min(log_data), max(log_data), n_bins + 1)
    bins = 10**log_bins
    plt.hist(mean_absolute_errors, bins=bins, density=True)
    plt.title(f"Distribution of the Mean absolute error. Train:{trained_on}, Eval:{eval_on}")
    
    kde = scipy.stats.gaussian_kde(mean_absolute_errors)
    x_vals = np.linspace(min(mean_absolute_errors), max(mean_absolute_errors), 500)
    plt.xscale("log")
    plt.plot(x_vals, kde(x_vals), 'r-', linewidth=2, label='KDE')

for trained_on in groups.keys():
    # baseline_dir = f"experiment1/trained{trained_on}/eval{trained_on}/aggregate/data_summary_trained{trained_on}_eval{trained_on}.txt"
    # with open(baseline_dir, 'r') as baseline_file:
    #         lines_baseline = baseline_file.readlines()
    # baseline_population = eval(lines_baseline[0])
    
    for eval_on in groups.keys(): 
        for i in [1,8,42]:
            # f"experiment1/trained{trained_on}/eval{eval_on}/aggregate/data_summary_trained{trained_on}_eval{eval_on}.txt"
            file_dir = f"experiment3/trained{trained_on}/eval{eval_on}/state{i}augment/data_summary.txt"
            with open(file_dir, 'r') as file:
                lines = file.readlines()
                
            # print(trained_on + eval_on + lines[1])
            population_2 = scipy.stats.zscore(eval(lines[0]))
            print(f"transformed distribution stats: avg:{np.average(population_2)} std:{np.std(population_2)}")
            
            ks_test = scipy.stats.kstest(population_2, 'norm')
            if ks_test.pvalue > 0.05:
                create_MAE_hist(population_2)
                plt.show()
            else:
                print(f"{trained_on}, {eval_on} state{i} is not normally distributed. pvalue:{ks_test.pvalue}")
# Out:
# transformed distribution stats: avg:-5.973337650505246e-17 std:1.0
# LDA, LDA state1 is not normally distributed. pvalue:2.3403341704536187e-69
# transformed distribution stats: avg:5.366636977040032e-17 std:1.0
# LDA, LDA state8 is not normally distributed. pvalue:9.836493699744073e-66
# transformed distribution stats: avg:1.093984196705312e-17 std:1.0
# LDA, LDA state42 is not normally distributed. pvalue:2.3612219785627784e-69
# transformed distribution stats: avg:1.1423516652091643e-17 std:0.9999999999999998
# LDA, Sigmoid state1 is not normally distributed. pvalue:4.929749495913789e-55
# transformed distribution stats: avg:-1.1423516652091642e-16 std:1.0
# LDA, Sigmoid state8 is not normally distributed. pvalue:2.848597512404257e-48
# transformed distribution stats: avg:3.427054995627493e-17 std:1.0
# LDA, Sigmoid state42 is not normally distributed. pvalue:2.0462931197135983e-46
# transformed distribution stats: avg:-1.1994692484696226e-16 std:1.0
# LDA, Centroid state1 is not normally distributed. pvalue:6.004623479873624e-77
# transformed distribution stats: avg:0.0 std:1.0
# LDA, Centroid state8 is not normally distributed. pvalue:1.1865167959430068e-59
# transformed distribution stats: avg:-1.1423516652091643e-17 std:1.0
# LDA, Centroid state42 is not normally distributed. pvalue:8.043377334115676e-59
# transformed distribution stats: avg:4.569406660836657e-17 std:1.0
# LDA, Gradient state1 is not normally distributed. pvalue:4.1466584884632135e-55
# transformed distribution stats: avg:3.427054995627493e-17 std:1.0
# LDA, Gradient state8 is not normally distributed. pvalue:3.272213894272082e-74
# transformed distribution stats: avg:-9.995577070580187e-17 std:1.0
# LDA, Gradient state42 is not normally distributed. pvalue:1.4423030776689554e-73
# transformed distribution stats: avg:-1.0240007400866136e-16 std:1.0
# LDA, ExtraTree state1 is not normally distributed. pvalue:2.6625800972529108e-86
# transformed distribution stats: avg:4.551114400384949e-17 std:1.0
# LDA, ExtraTree state8 is not normally distributed. pvalue:2.723212052925846e-62
# transformed distribution stats: avg:1.8204457601539795e-16 std:1.0
# LDA, ExtraTree state42 is not normally distributed. pvalue:3.8142827262897743e-59
# transformed distribution stats: avg:6.826671600577423e-17 std:1.0
# Sigmoid, LDA state1 is not normally distributed. pvalue:5.855679053964644e-15
# transformed distribution stats: avg:-1.8204457601539795e-16 std:1.0
# Sigmoid, LDA state8 is not normally distributed. pvalue:5.587470944261941e-15
# transformed distribution stats: avg:1.280000925108267e-16 std:1.0
# Sigmoid, LDA state42 is not normally distributed. pvalue:3.082665175902889e-18
# transformed distribution stats: avg:9.138813321673314e-17 std:1.0
# Sigmoid, Sigmoid state1 is not normally distributed. pvalue:8.336026557001671e-44
# transformed distribution stats: avg:1.0773961118424567e-16 std:1.0
# Sigmoid, Sigmoid state8 is not normally distributed. pvalue:9.915055639185678e-42
# transformed distribution stats: avg:-1.5862770852227025e-16 std:1.0000000000000002
# Sigmoid, Sigmoid state42 is not normally distributed. pvalue:5.758502539973512e-41
# transformed distribution stats: avg:4.569406660836657e-17 std:1.0
# Sigmoid, Centroid state1 is not normally distributed. pvalue:6.297282386153258e-46
# transformed distribution stats: avg:-2.2847033304183285e-17 std:0.9999999999999999
# Sigmoid, Centroid state8 is not normally distributed. pvalue:2.8478513373726956e-39
# transformed distribution stats: avg:5.711758326045821e-17 std:1.0
# Sigmoid, Centroid state42 is not normally distributed. pvalue:8.972910413424723e-30
# transformed distribution stats: avg:1.1423516652091643e-17 std:1.0
# Sigmoid, Gradient state1 is not normally distributed. pvalue:3.795015885651967e-12
# transformed distribution stats: avg:-1.1709104568393933e-16 std:0.9999999999999999
# Sigmoid, Gradient state8 is not normally distributed. pvalue:1.7548703594408347e-22
# transformed distribution stats: avg:2.1704681638974121e-16 std:1.0
# Sigmoid, Gradient state42 is not normally distributed. pvalue:4.402676238376221e-18
# transformed distribution stats: avg:-9.102228800769898e-17 std:1.0
# Sigmoid, ExtraTree state1 is not normally distributed. pvalue:3.7979713001654784e-16
# transformed distribution stats: avg:-3.4133358002887116e-17 std:1.0
# Sigmoid, ExtraTree state8 is not normally distributed. pvalue:6.066283070915344e-23
# transformed distribution stats: avg:-2.616890780221346e-16 std:1.0
# Sigmoid, ExtraTree state42 is not normally distributed. pvalue:4.812976097750786e-27
# transformed distribution stats: avg:0.0 std:1.0
# Centroid, LDA state1 is not normally distributed. pvalue:4.074933010070438e-14
# transformed distribution stats: avg:4.551114400384949e-17 std:1.0
# Centroid, LDA state8 is not normally distributed. pvalue:1.0991675061272987e-27
# transformed distribution stats: avg:-9.102228800769898e-17 std:1.0
# Centroid, LDA state42 is not normally distributed. pvalue:3.2696730533769062e-25
# transformed distribution stats: avg:7.99646165646415e-17 std:0.9999999999999999
# Centroid, Sigmoid state1 is not normally distributed. pvalue:4.220385465779202e-15
# transformed distribution stats: avg:2.2847033304183285e-17 std:0.9999999999999999
# Centroid, Sigmoid state8 is not normally distributed. pvalue:7.926996566776286e-45
# transformed distribution stats: avg:-7.99646165646415e-17 std:0.9999999999999999
# Centroid, Sigmoid state42 is not normally distributed. pvalue:8.503760574164863e-44
# transformed distribution stats: avg:-6.854109991254986e-17 std:1.0
# Centroid, Centroid state1 is not normally distributed. pvalue:9.799410080580053e-41
# transformed distribution stats: avg:-5.3869805592122834e-17 std:1.0
# Centroid, Centroid state8 is not normally distributed. pvalue:3.6051247162989997e-34
# transformed distribution stats: avg:-2.187968393410624e-17 std:1.0
# Centroid, Centroid state42 is not normally distributed. pvalue:1.8410744077323244e-39
# transformed distribution stats: avg:4.569406660836657e-17 std:1.0
# Centroid, Gradient state1 is not normally distributed. pvalue:0.000787427133069926
# transformed distribution stats: avg:-1.1423516652091643e-17 std:1.0
# Centroid, Gradient state8 is not normally distributed. pvalue:2.6657154283694033e-08
# transformed distribution stats: avg:1.1423516652091643e-17 std:1.0
# Centroid, Gradient state42 is not normally distributed. pvalue:1.2418612601084253e-06
# transformed distribution stats: avg:7.96445020067366e-17 std:1.0
# Centroid, ExtraTree state1 is not normally distributed. pvalue:3.243641023679849e-17
# transformed distribution stats: avg:-1.0524452050890195e-16 std:1.0
# Centroid, ExtraTree state8 is not normally distributed. pvalue:1.4110937621684584e-18
# transformed distribution stats: avg:-9.102228800769898e-17 std:1.0
# Centroid, ExtraTree state42 is not normally distributed. pvalue:5.499665165069424e-19
# transformed distribution stats: avg:-1.1377786000962372e-17 std:1.0
# Gradient, LDA state1 is not normally distributed. pvalue:2.815019467475627e-37
# transformed distribution stats: avg:-7.96445020067366e-17 std:1.0
# Gradient, LDA state8 is not normally distributed. pvalue:6.256516700711963e-33
# transformed distribution stats: avg:-1.1377786000962372e-17 std:1.0
# Gradient, LDA state42 is not normally distributed. pvalue:2.916804968733496e-34
# transformed distribution stats: avg:-1.0281164986882478e-16 std:1.0
# Gradient, Sigmoid state1 is not normally distributed. pvalue:1.4615122576307661e-36
# transformed distribution stats: avg:0.0 std:1.0
# Gradient, Sigmoid state8 is not normally distributed. pvalue:1.1724951932391508e-29
# transformed distribution stats: avg:-1.2565868317300807e-16 std:1.0000000000000002
# Gradient, Sigmoid state42 is not normally distributed. pvalue:8.993319703883459e-29
# transformed distribution stats: avg:6.282934158650404e-17 std:1.0
# Gradient, Centroid state1 is not normally distributed. pvalue:4.691207619262736e-44
# transformed distribution stats: avg:-9.709989154277897e-17 std:1.0
# Gradient, Centroid state8 is not normally distributed. pvalue:7.803768852615094e-40
# transformed distribution stats: avg:9.138813321673314e-17 std:1.0
# Gradient, Centroid state42 is not normally distributed. pvalue:3.998241213653398e-40
# transformed distribution stats: avg:-2.2847033304183285e-17 std:0.9999999999999999
# Gradient, Gradient state1 is not normally distributed. pvalue:2.8989593218329502e-65
# transformed distribution stats: avg:7.541772782897197e-17 std:1.0
# Gradient, Gradient state8 is not normally distributed. pvalue:2.3099123469086056e-53
# transformed distribution stats: avg:2.187968393410624e-17 std:1.0
# Gradient, Gradient state42 is not normally distributed. pvalue:1.7519677619223727e-81
# transformed distribution stats: avg:4.551114400384949e-17 std:1.0
# Gradient, ExtraTree state1 is not normally distributed. pvalue:4.573474213804186e-38
# transformed distribution stats: avg:3.4133358002887116e-17 std:0.9999999999999999
# Gradient, ExtraTree state8 is not normally distributed. pvalue:4.2620391409002206e-27
# transformed distribution stats: avg:1.1377786000962372e-16 std:1.0
# Gradient, ExtraTree state42 is not normally distributed. pvalue:3.9773205566438104e-27
# transformed distribution stats: avg:-6.257782300529305e-17 std:1.0
# ExtraTree, LDA state1 is not normally distributed. pvalue:1.1469956248896614e-24
# transformed distribution stats: avg:7.111116250601483e-17 std:1.0
# ExtraTree, LDA state8 is not normally distributed. pvalue:2.0939838339117817e-43
# transformed distribution stats: avg:-1.1377786000962372e-16 std:1.0000000000000002
# ExtraTree, LDA state42 is not normally distributed. pvalue:1.0461625777864419e-45
# transformed distribution stats: avg:1.3137044149905389e-16 std:1.0
# ExtraTree, Sigmoid state1 is not normally distributed. pvalue:2.8432459980975273e-33
# transformed distribution stats: avg:9.138813321673314e-17 std:0.9999999999999999
# ExtraTree, Sigmoid state8 is not normally distributed. pvalue:4.3945395292279095e-33
# transformed distribution stats: avg:-1.1423516652091642e-16 std:1.0
# ExtraTree, Sigmoid state42 is not normally distributed. pvalue:3.8175179504559084e-36
# transformed distribution stats: avg:-1.1709104568393933e-16 std:1.0
# ExtraTree, Centroid state1 is not normally distributed. pvalue:3.202694580808018e-47
# transformed distribution stats: avg:7.99646165646415e-17 std:1.0
# ExtraTree, Centroid state8 is not normally distributed. pvalue:5.570613752125569e-36
# transformed distribution stats: avg:-3.998230828232075e-17 std:1.0
# ExtraTree, Centroid state42 is not normally distributed. pvalue:1.9487569517244175e-38
# transformed distribution stats: avg:6.854109991254986e-17 std:1.0
# ExtraTree, Gradient state1 is not normally distributed. pvalue:1.0774994899819273e-27
# transformed distribution stats: avg:-9.424401237975605e-17 std:1.0
# ExtraTree, Gradient state8 is not normally distributed. pvalue:4.560332445257101e-48
# transformed distribution stats: avg:5.711758326045821e-18 std:0.9999999999999999
# ExtraTree, Gradient state42 is not normally distributed. pvalue:1.8376886755078178e-45
# transformed distribution stats: avg:6.826671600577423e-17 std:1.0
# ExtraTree, ExtraTree state1 is not normally distributed. pvalue:8.647152454724869e-32
# transformed distribution stats: avg:-1.8246565721936108e-16 std:0.9999999999999998
# ExtraTree, ExtraTree state8 is not normally distributed. pvalue:2.733856536047906e-97
# transformed distribution stats: avg:0.0 std:1.0
# ExtraTree, ExtraTree state42 is not normally distributed. pvalue:7.058471979570527e-86
